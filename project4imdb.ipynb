# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


data = pd.read_csv(r'C:\Users\PRAGNYAN DASH\Downloads\archive\movies.csv')
 #plot a graph to show the distribution of genre in the top 250 movies 
genre_counts = data['genre'].value_counts()
plt.figure(figsize=(12, 6))
sns.barplot(x=genre_counts.index, y=genre_counts.values, palette='viridis')
plt.title("Genre Distribution in Top 250 Movies")
plt.xlabel("genre")
plt.ylabel("Count")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

data=data.replace(',','',regex=True)
# Out:
# Movie with the maximum number of votes:
#          title                 genre duration imbd_votes
# 184  Gone Girl  DramaMysteryThriller   2h 29m     996836
# Movie with the minimum number of votes:
#              title                  genre duration imbd_votes
# 143  Jurassic Park  ActionAdventureSci-Fi    2h 7m    1001679
# Movies of ActionAdventure genre with the maximum number of votes:
#                       title            genre imbd_votes
# 55  Raiders of the Lost Ark  ActionAdventure     976471
#
# Movies of ActionAdventureComedy genre with the maximum number of votes:
#            title                  genre imbd_votes
# 186  The General  ActionAdventureComedy      92925
#
# Movies of ActionAdventureDrama genre with the maximum number of votes:
#                                                title                 genre  \
# 8  The Lord of the Rings: The Fellowship of the Ring  ActionAdventureDrama
#
#   imbd_votes
# 8    1895357
#
# Movies of ActionAdventureFantasy genre with the maximum number of votes:
#                        title                   genre imbd_votes
# 151  Spider-Man: No Way Home  ActionAdventureFantasy     776160
#
# Movies of ActionAdventureMystery genre with the maximum number of votes:
#                  title                   genre imbd_votes
# 97  North by Northwest  ActionAdventureMystery     331797
#
# Movies of ActionAdventureSci-Fi genre with the maximum number of votes:
#      title                  genre imbd_votes
# 64  Aliens  ActionAdventureSci-Fi     725492
#
# Movies of ActionBiographyDrama genre with the maximum number of votes:
#     title                 genre imbd_votes
# 217  Rush  ActionBiographyDrama     486172
#
# Movies of ActionComedyCrime genre with the maximum number of votes:
#                                   title              genre imbd_votes
# 159  Lock Stock and Two Smoking Barrels  ActionComedyCrime     589353
#
# Movies of ActionComedyRomance genre with the maximum number of votes:
#             title                genre imbd_votes
# 194  Sherlock Jr.  ActionComedyRomance      51440
#
# Movies of ActionCrimeDrama genre with the maximum number of votes:
#     title             genre imbd_votes
# 108  Heat  ActionCrimeDrama     664714
#
# Movies of ActionDrama genre with the maximum number of votes:
#                  title        genre imbd_votes
# 112  Top Gun: Maverick  ActionDrama     541686
#
# Movies of ActionDramaMystery genre with the maximum number of votes:
#        title               genre imbd_votes
# 44  Harakiri  ActionDramaMystery      59327
#
# Movies of ActionDramaSci-Fi genre with the maximum number of votes:
#             title              genre imbd_votes
# 175  Blade Runner  ActionDramaSci-Fi     779533
#
# Movies of ActionDramaSport genre with the maximum number of votes:
#        title             genre imbd_votes
# 168  Warrior  ActionDramaSport     478019
#
# Movies of ActionDramaThriller genre with the maximum number of votes:
#                     title                genre imbd_votes
# 68  The Dark Knight Rises  ActionDramaThriller    1722652
#
# Movies of ActionDramaWar genre with the maximum number of votes:
#     title           genre imbd_votes
# 122  1917  ActionDramaWar     606899
#
# Movies of ActionSci-Fi genre with the maximum number of votes:
#               title         genre imbd_votes
# 214  The Terminator  ActionSci-Fi     876163
#
# Movies of ActionThriller genre with the maximum number of votes:
#         title           genre imbd_votes
# 117  Die Hard  ActionThriller     893737
#
# Movies of AdventureBiographyDrama genre with the maximum number of votes:
#              title                    genre imbd_votes
# 220  Into the Wild  AdventureBiographyDrama     629900
#
# Movies of AdventureComedyCrime genre with the maximum number of votes:
#                         title                 genre imbd_votes
# 183  The Grand Budapest Hotel  AdventureComedyCrime     824947
#
# Movies of AdventureComedyDrama genre with the maximum number of votes:
#              title                 genre imbd_votes
# 176  The Gold Rush  AdventureComedyDrama     112833
#
# Movies of AdventureComedyFantasy genre with the maximum number of votes:
#                                title                   genre imbd_votes
# 146  Monty Python and the Holy Grail  AdventureComedyFantasy     547240
#
# Movies of AdventureComedySci-Fi genre with the maximum number of votes:
#                  title                  genre imbd_votes
# 29  Back to the Future  AdventureComedySci-Fi    1221395
#
# Movies of AdventureDrama genre with the maximum number of votes:
#            title           genre imbd_votes
# 216  Stand by Me  AdventureDrama     411166
#
# Movies of AdventureDramaHistory genre with the maximum number of votes:
#                 title                  genre imbd_votes
# 147  The Great Escape  AdventureDramaHistory     247453
#
# Movies of AdventureDramaSci-Fi genre with the maximum number of votes:
#            title                 genre imbd_votes
# 24  Interstellar  AdventureDramaSci-Fi    1870060
#
# Movies of AdventureDramaThriller genre with the maximum number of votes:
#                  title                   genre imbd_votes
# 192  The Wages of Fear  AdventureDramaThriller      62539
#
# Movies of AdventureDramaWar genre with the maximum number of votes:
#                             title              genre imbd_votes
# 165  The Bridge on the River Kwai  AdventureDramaWar     223494
#
# Movies of AdventureDramaWestern genre with the maximum number of votes:
#                   title                  genre imbd_votes
# 249  Dances with Wolves  AdventureDramaWestern     271823
#
# Movies of AdventureFamilyFantasy genre with the maximum number of votes:
#                                             title                   genre  \
# 179  Harry Potter and the Deathly Hallows: Part 2  AdventureFamilyFantasy
#
#     imbd_votes
# 179     889002
#
# Movies of AdventureSci-Fi genre with the maximum number of votes:
#                     title            genre imbd_votes
# 89  2001: A Space Odyssey  AdventureSci-Fi     677258
#
# Movies of AdventureThriller genre with the maximum number of votes:
#     title              genre imbd_votes
# 203  Jaws  AdventureThriller     615988
#
# Movies of AdventureWestern genre with the maximum number of votes:
#                            title             genre imbd_votes
# 9  The Good the Bad and the Ugly  AdventureWestern     769389
#
# Movies of AnimationActionAdventure genre with the maximum number of votes:
#                         title                     genre imbd_votes
# 200  How to Train Your Dragon  AnimationActionAdventure     751071
#
# Movies of AnimationAdventureComedy genre with the maximum number of votes:
#              title                     genre imbd_votes
# 201  Monsters Inc.  AnimationAdventureComedy     920862
#
# Movies of AnimationAdventureDrama genre with the maximum number of votes:
#             title                    genre imbd_votes
# 35  The Lion King  AnimationAdventureDrama    1071355
#
# Movies of AnimationAdventureFamily genre with the maximum number of votes:
#             title                     genre imbd_votes
# 30  Spirited Away  AnimationAdventureFamily     776114
#
# Movies of AnimationComedyDrama genre with the maximum number of votes:
#             title                 genre imbd_votes
# 198  Mary and Max  AnimationComedyDrama     179400
#
# Movies of AnimationComedyFamily genre with the maximum number of votes:
#                   title                  genre imbd_votes
# 171  My Neighbor Totoro  AnimationComedyFamily     346498
#
# Movies of AnimationDramaFantasy genre with the maximum number of votes:
#          title                  genre imbd_votes
# 81  Your Name.  AnimationDramaFantasy     276854
#
# Movies of AnimationDramaWar genre with the maximum number of votes:
#                      title              genre imbd_votes
# 43  Grave of the Fireflies  AnimationDramaWar     282456
#
# Movies of BiographyComedyCrime genre with the maximum number of votes:
#                        title                 genre imbd_votes
# 131  The Wolf of Wall Street  BiographyComedyCrime    1437576
#
# Movies of BiographyComedyDrama genre with the maximum number of votes:
#                title                 genre imbd_votes
# 45  The Intouchables  BiographyComedyDrama     870273
#
# Movies of BiographyCrimeDrama genre with the maximum number of votes:
#          title                genre imbd_votes
# 213  Spotlight  BiographyCrimeDrama     476580
#
# Movies of BiographyDrama genre with the maximum number of votes:
#                 title           genre imbd_votes
# 142  A Beautiful Mind  BiographyDrama     941601
#
# Movies of BiographyDramaFamily genre with the maximum number of votes:
#                    title                 genre imbd_votes
# 231  Hachi: A Dog's Tale  BiographyDramaFamily     290951
#
# Movies of BiographyDramaHistory genre with the maximum number of votes:
#         title                  genre imbd_votes
# 106  Hamilton  BiographyDramaHistory      98498
#
# Movies of BiographyDramaMusic genre with the maximum number of votes:
#           title                genre imbd_votes
# 31  The Pianist  BiographyDramaMusic     843709
#
# Movies of BiographyDramaSport genre with the maximum number of votes:
#            title                genre imbd_votes
# 156  Raging Bull  BiographyDramaSport     358918
#
# Movies of Comedy genre with the maximum number of votes:
#              title   genre imbd_votes
# 243  Life of Brian  Comedy     404989
#
# Movies of ComedyCrime genre with the maximum number of votes:
#       title        genre imbd_votes
# 118  Snatch  ComedyCrime     865529
#
# Movies of ComedyCrimeDrama genre with the maximum number of votes:
#                                         title             genre imbd_votes
# 164  Three Billboards Outside Ebbing Missouri  ComedyCrimeDrama     518061
#
# Movies of ComedyDrama genre with the maximum number of votes:
#                   title        genre imbd_votes
# 204  Dead Poets Society  ComedyDrama     501186
#
# Movies of ComedyDramaFamily genre with the maximum number of votes:
#        title              genre imbd_votes
# 127  The Kid  ComedyDramaFamily     128080
#
# Movies of ComedyDramaFantasy genre with the maximum number of votes:
#              title               genre imbd_votes
# 224  Groundhog Day  ComedyDramaFantasy     643209
#
# Movies of ComedyDramaRomance genre with the maximum number of votes:
#                 title               genre imbd_votes
# 25  Life Is Beautiful  ComedyDramaRomance     703472
#
# Movies of ComedyDramaThriller genre with the maximum number of votes:
#           title                genre imbd_votes
# 195  Wild Tales  ComedyDramaThriller     202365
#
# Movies of ComedyDramaWar genre with the maximum number of votes:
#                  title           genre imbd_votes
# 61  The Great Dictator  ComedyDramaWar     226622
# Movies of ComedyMusicRomance genre with the maximum number of votes:
#                 title               genre imbd_votes
# 128  Some Like It Hot  ComedyMusicRomance     270788
#
# Movies of ComedyMusicalRomance genre with the maximum number of votes:
#                   title                 genre imbd_votes
# 82  Singin' in the Rain  ComedyMusicalRomance     246258
#
# Movies of ComedyRomance genre with the maximum number of votes:
#       title          genre imbd_votes
# 101  Amélie  ComedyRomance     763676
#
# Movies of ComedyRomanceWar genre with the maximum number of votes:
#                   title             genre imbd_votes
# 226  To Be or Not to Be  ComedyRomanceWar      38888
#
# Movies of ComedyWar genre with the maximum number of votes:
#                                                 title      genre imbd_votes
# 67  Dr. Strangelove or: How I Learned to Stop Worr...  ComedyWar     495942
#
# Movies of CrimeDrama genre with the maximum number of votes:
#         title       genre imbd_votes
# 105  Scarface  CrimeDrama     853851
#
# Movies of CrimeDramaFantasy genre with the maximum number of votes:
#              title              genre imbd_votes
# 26  The Green Mile  CrimeDramaFantasy    1317747
#
# Movies of CrimeDramaFilm-Noir genre with the maximum number of votes:
#                 title                genre imbd_votes
# 103  Double Indemnity  CrimeDramaFilm-Noir     159388
#
# Movies of CrimeDramaMystery genre with the maximum number of votes:
#          title              genre imbd_votes
# 167  Prisoners  CrimeDramaMystery     731875
#
# Movies of CrimeDramaThriller genre with the maximum number of votes:
#                       title               genre imbd_votes
# 148  No Country for Old Men  CrimeDramaThriller     987934
#
# Movies of CrimeMysteryThriller genre with the maximum number of votes:
#    title                 genre imbd_votes
# 95     M  CrimeMysteryThriller     160158
#
# Movies of CrimeSci-Fi genre with the maximum number of votes:
#                   title        genre imbd_votes
# 102  A Clockwork Orange  CrimeSci-Fi     839209
#
# Movies of CrimeThriller genre with the maximum number of votes:
#      title          genre imbd_votes
# 169  Fargo  CrimeThriller     686205
#
# Movies of Drama genre with the maximum number of votes:
#                    title  genre imbd_votes
# 232  The Grapes of Wrath  Drama      95146
#
# Movies of DramaFamily genre with the maximum number of votes:
#                     title        genre imbd_votes
# 234  My Father and My Son  DramaFamily      87525
#
# Movies of DramaFamilyFantasy genre with the maximum number of votes:
#                     title               genre imbd_votes
# 20  It's a Wonderful Life  DramaFamilyFantasy     467723
#
# Movies of DramaFamilySport genre with the maximum number of votes:
#                   title             genre imbd_votes
# 174  Children of Heaven  DramaFamilySport      75814
#
# Movies of DramaFantasy genre with the maximum number of votes:
#                 title         genre imbd_votes
# 199  The Seventh Seal  DramaFantasy     187934
#
# Movies of DramaFantasyWar genre with the maximum number of votes:
#                title            genre imbd_votes
# 137  Pan's Labyrinth  DramaFantasyWar     675640
#
# Movies of DramaFilm-Noir genre with the maximum number of votes:
#            title           genre imbd_votes
# 58  Sunset Blvd.  DramaFilm-Noir     224680
#
# Movies of DramaFilm-NoirMystery genre with the maximum number of votes:
#        title                  genre imbd_votes
# 236  Rebecca  DramaFilm-NoirMystery     139329
#
# Movies of DramaHorror genre with the maximum number of votes:
#           title        genre imbd_votes
# 60  The Shining  DramaHorror    1035594
#
# Movies of DramaMusic genre with the maximum number of votes:
#        title       genre imbd_votes
# 41  Whiplash  DramaMusic     883875
#
# Movies of DramaMystery genre with the maximum number of votes:
#            title         genre imbd_votes
# 94  Citizen Kane  DramaMystery     446582
#
# Movies of DramaMysteryRomance genre with the maximum number of votes:
#                         title                genre imbd_votes
# 162  The Secret in Their Eyes  DramaMysteryRomance     212280
#
# Movies of DramaMysterySci-Fi genre with the maximum number of votes:
#            title               genre imbd_votes
# 40  The Prestige  DramaMysterySci-Fi    1348423
#
# Movies of DramaMysteryThriller genre with the maximum number of votes:
#          title                 genre imbd_votes
# 184  Gone Girl  DramaMysteryThriller     996836
#
# Movies of DramaMysteryWar genre with the maximum number of votes:
#              title            genre imbd_votes
# 52  Apocalypse Now  DramaMysteryWar     675280
#
# Movies of DramaRomance genre with the maximum number of votes:
#                 title         genre imbd_votes
# 80  Good Will Hunting  DramaRomance     987400
#
# Movies of DramaRomanceSci-Fi genre with the maximum number of votes:
#                                     title               genre imbd_votes
# 90  Eternal Sunshine of the Spotless Mind  DramaRomanceSci-Fi    1020184
#
# Movies of DramaRomanceThriller genre with the maximum number of votes:
#               title                 genre imbd_votes
# 238  The Handmaiden  DramaRomanceThriller     153302
#
# Movies of DramaRomanceWar genre with the maximum number of votes:
#                            title            genre imbd_votes
# 222  The Best Years of Our Lives  DramaRomanceWar      66194
#
# Movies of DramaSci-Fi genre with the maximum number of votes:
#           title        genre imbd_votes
# 114  Metropolis  DramaSci-Fi     176619
#
# Movies of DramaSport genre with the maximum number of votes:
#                    title       genre imbd_votes
# 173  Million Dollar Baby  DramaSport     694061
#
# Movies of DramaThriller genre with the maximum number of votes:
#        title          genre imbd_votes
# 33  Parasite  DramaThriller     828575
#
# Movies of DramaThrillerWar genre with the maximum number of votes:
#            title             genre imbd_votes
# 92  Come and See  DramaThrillerWar      83154
#
# Movies of DramaWar genre with the maximum number of votes:
#                      title     genre imbd_votes
# 133  Judgment at Nuremberg  DramaWar      78828
#
# Movies of DramaWestern genre with the maximum number of votes:
#           title         genre imbd_votes
# 139  Unforgiven  DramaWestern     416587
#
# Movies of Film-NoirMysteryThriller genre with the maximum number of votes:
#              title                     genre imbd_votes
# 188  The Third Man  Film-NoirMysteryThriller     173749
#
# Movies of Horror genre with the maximum number of votes:
#             title   genre imbd_votes
# 225  The Exorcist  Horror     415311
#
# Movies of HorrorMysterySci-Fi genre with the maximum number of votes:
#          title                genre imbd_votes
# 152  The Thing  HorrorMysterySci-Fi     432488
#
# Movies of HorrorMysteryThriller genre with the maximum number of votes:
#      title                  genre imbd_votes
# 32  Psycho  HorrorMysteryThriller     679428
#
# Movies of HorrorSci-Fi genre with the maximum number of votes:
#     title         genre imbd_votes
# 50  Alien  HorrorSci-Fi     892980
#
# Movies of MysteryRomanceThriller genre with the maximum number of votes:
#       title                   genre imbd_votes
# 99  Vertigo  MysteryRomanceThriller     407006
#
# Movies of MysteryThriller genre with the maximum number of votes:
#           title            genre imbd_votes
# 49  Rear Window  MysteryThriller     497077
#
# Movies of Western genre with the maximum number of votes:
#                            title    genre imbd_votes
# 47  Once Upon a Time in the West  Western     333809

# %%
#find out which movie has the maximum number of votes and which genre it belongs to and its duration.
max_votes_movie = data[data['imbd_votes'] == data['imbd_votes'].max()]
max_votes_movie_details = max_votes_movie[['title', 'genre', 'duration', 'imbd_votes']]

print("Movie with the maximum number of votes:")
print(max_votes_movie_details)
# Out:
# Movie with the maximum number of votes:
#          title                 genre duration imbd_votes
# 184  Gone Girl  DramaMysteryThriller   2h 29m     996836

# %%
#find out which movie has the minimum number of votes and which genre it belongs to and its duration.
min_votes_movie = data[data['imbd_votes'] == data['imbd_votes'].min()]
min_votes_movie_details = min_votes_movie[['title', 'genre', 'duration', 'imbd_votes']]

print("Movie with the minimum number of votes:")
print(min_votes_movie_details)
# Out:
# Movie with the minimum number of votes:
#              title                  genre duration imbd_votes
# 143  Jurassic Park  ActionAdventureSci-Fi    2h 7m    1001679

# %%
# Find the movies with the maximum number of votes for each genre
max_votes_per_genre = data.groupby('genre')['imbd_votes'].max()

max_votes_movies = data[data.groupby('genre')['imbd_votes'].transform(max) == data['imbd_votes']]

for genre in max_votes_per_genre.index:
    genre_movies = max_votes_movies[max_votes_movies['genre'] == genre]
    print(f"Movies of {genre} genre with the maximum number of votes:")
    print(genre_movies[['title', 'genre' , 'imbd_votes']])
    print()
# Out:
# Movies of ActionAdventure genre with the maximum number of votes:
#                       title            genre imbd_votes
# 55  Raiders of the Lost Ark  ActionAdventure     976471
#
# Movies of ActionAdventureComedy genre with the maximum number of votes:
#            title                  genre imbd_votes
# 186  The General  ActionAdventureComedy      92925
#
# Movies of ActionAdventureDrama genre with the maximum number of votes:
#                                                title                 genre  \
# 8  The Lord of the Rings: The Fellowship of the Ring  ActionAdventureDrama
#
#   imbd_votes
# 8    1895357
#
# Movies of ActionAdventureFantasy genre with the maximum number of votes:
#                        title                   genre imbd_votes
# 151  Spider-Man: No Way Home  ActionAdventureFantasy     776160
#
# Movies of ActionAdventureMystery genre with the maximum number of votes:
#                  title                   genre imbd_votes
# 97  North by Northwest  ActionAdventureMystery     331797
#
# Movies of ActionAdventureSci-Fi genre with the maximum number of votes:
#      title                  genre imbd_votes
# 64  Aliens  ActionAdventureSci-Fi     725492
#
# Movies of ActionBiographyDrama genre with the maximum number of votes:
#     title                 genre imbd_votes
# 217  Rush  ActionBiographyDrama     486172
#
# Movies of ActionComedyCrime genre with the maximum number of votes:
#                                   title              genre imbd_votes
# 159  Lock Stock and Two Smoking Barrels  ActionComedyCrime     589353
#
# Movies of ActionComedyRomance genre with the maximum number of votes:
#             title                genre imbd_votes
# 194  Sherlock Jr.  ActionComedyRomance      51440
#
# Movies of ActionCrimeDrama genre with the maximum number of votes:
#     title             genre imbd_votes
# 108  Heat  ActionCrimeDrama     664714
#
# Movies of ActionDrama genre with the maximum number of votes:
#                  title        genre imbd_votes
# 112  Top Gun: Maverick  ActionDrama     541686
#
# Movies of ActionDramaMystery genre with the maximum number of votes:
#        title               genre imbd_votes
# 44  Harakiri  ActionDramaMystery      59327
#
# Movies of ActionDramaSci-Fi genre with the maximum number of votes:
#             title              genre imbd_votes
# 175  Blade Runner  ActionDramaSci-Fi     779533
#
# Movies of ActionDramaSport genre with the maximum number of votes:
#        title             genre imbd_votes
# 168  Warrior  ActionDramaSport     478019
#
# Movies of ActionDramaThriller genre with the maximum number of votes:
#                     title                genre imbd_votes
# 68  The Dark Knight Rises  ActionDramaThriller    1722652
#
# Movies of ActionDramaWar genre with the maximum number of votes:
#     title           genre imbd_votes
# 122  1917  ActionDramaWar     606899
#
# Movies of ActionSci-Fi genre with the maximum number of votes:
#               title         genre imbd_votes
# 214  The Terminator  ActionSci-Fi     876163
#
# Movies of ActionThriller genre with the maximum number of votes:
#         title           genre imbd_votes
# 117  Die Hard  ActionThriller     893737
#
# Movies of AdventureBiographyDrama genre with the maximum number of votes:
#              title                    genre imbd_votes
# 220  Into the Wild  AdventureBiographyDrama     629900
#
# Movies of AdventureComedyCrime genre with the maximum number of votes:
#                         title                 genre imbd_votes
# 183  The Grand Budapest Hotel  AdventureComedyCrime     824947
#
# Movies of AdventureComedyDrama genre with the maximum number of votes:
#              title                 genre imbd_votes
# 176  The Gold Rush  AdventureComedyDrama     112833
#
# Movies of AdventureComedyFantasy genre with the maximum number of votes:
#                                title                   genre imbd_votes
# 146  Monty Python and the Holy Grail  AdventureComedyFantasy     547240
#
# Movies of AdventureComedySci-Fi genre with the maximum number of votes:
#                  title                  genre imbd_votes
# 29  Back to the Future  AdventureComedySci-Fi    1221395
#
# Movies of AdventureDrama genre with the maximum number of votes:
#            title           genre imbd_votes
# 216  Stand by Me  AdventureDrama     411166
#
# Movies of AdventureDramaHistory genre with the maximum number of votes:
#                 title                  genre imbd_votes
# 147  The Great Escape  AdventureDramaHistory     247453
#
# Movies of AdventureDramaSci-Fi genre with the maximum number of votes:
#            title                 genre imbd_votes
# 24  Interstellar  AdventureDramaSci-Fi    1870060
#
# Movies of AdventureDramaThriller genre with the maximum number of votes:
#                  title                   genre imbd_votes
# 192  The Wages of Fear  AdventureDramaThriller      62539
#
# Movies of AdventureDramaWar genre with the maximum number of votes:
#                             title              genre imbd_votes
# 165  The Bridge on the River Kwai  AdventureDramaWar     223494
#
# Movies of AdventureDramaWestern genre with the maximum number of votes:
#                   title                  genre imbd_votes
# 249  Dances with Wolves  AdventureDramaWestern     271823
#
# Movies of AdventureFamilyFantasy genre with the maximum number of votes:
#                                             title                   genre  \
# 179  Harry Potter and the Deathly Hallows: Part 2  AdventureFamilyFantasy
#
#     imbd_votes
# 179     889002
#
# Movies of AdventureSci-Fi genre with the maximum number of votes:
#                     title            genre imbd_votes
# 89  2001: A Space Odyssey  AdventureSci-Fi     677258
#
# Movies of AdventureThriller genre with the maximum number of votes:
#     title              genre imbd_votes
# 203  Jaws  AdventureThriller     615988
#
# Movies of AdventureWestern genre with the maximum number of votes:
#                            title             genre imbd_votes
# 9  The Good the Bad and the Ugly  AdventureWestern     769389
#
# Movies of AnimationActionAdventure genre with the maximum number of votes:
#                         title                     genre imbd_votes
# 200  How to Train Your Dragon  AnimationActionAdventure     751071
#
# Movies of AnimationAdventureComedy genre with the maximum number of votes:
#              title                     genre imbd_votes
# 201  Monsters Inc.  AnimationAdventureComedy     920862
#
# Movies of AnimationAdventureDrama genre with the maximum number of votes:
#             title                    genre imbd_votes
# 35  The Lion King  AnimationAdventureDrama    1071355
#
# Movies of AnimationAdventureFamily genre with the maximum number of votes:
#             title                     genre imbd_votes
# 30  Spirited Away  AnimationAdventureFamily     776114
#
# Movies of AnimationComedyDrama genre with the maximum number of votes:
#             title                 genre imbd_votes
# 198  Mary and Max  AnimationComedyDrama     179400
#
# Movies of AnimationComedyFamily genre with the maximum number of votes:
#                   title                  genre imbd_votes
# 171  My Neighbor Totoro  AnimationComedyFamily     346498
#
# Movies of AnimationDramaFantasy genre with the maximum number of votes:
#          title                  genre imbd_votes
# 81  Your Name.  AnimationDramaFantasy     276854
#
# Movies of AnimationDramaWar genre with the maximum number of votes:
#                      title              genre imbd_votes
# 43  Grave of the Fireflies  AnimationDramaWar     282456
#
# Movies of BiographyComedyCrime genre with the maximum number of votes:
#                        title                 genre imbd_votes
# 131  The Wolf of Wall Street  BiographyComedyCrime    1437576
#
# Movies of BiographyComedyDrama genre with the maximum number of votes:
#                title                 genre imbd_votes
# 45  The Intouchables  BiographyComedyDrama     870273
#
# Movies of BiographyCrimeDrama genre with the maximum number of votes:
#          title                genre imbd_votes
# 213  Spotlight  BiographyCrimeDrama     476580
#
# Movies of BiographyDrama genre with the maximum number of votes:
#                 title           genre imbd_votes
# 142  A Beautiful Mind  BiographyDrama     941601
#
# Movies of BiographyDramaFamily genre with the maximum number of votes:
#                    title                 genre imbd_votes
# 231  Hachi: A Dog's Tale  BiographyDramaFamily     290951
#
# Movies of BiographyDramaHistory genre with the maximum number of votes:
#         title                  genre imbd_votes
# 106  Hamilton  BiographyDramaHistory      98498
#
# Movies of BiographyDramaMusic genre with the maximum number of votes:
#           title                genre imbd_votes
# 31  The Pianist  BiographyDramaMusic     843709
#
# Movies of BiographyDramaSport genre with the maximum number of votes:
#            title                genre imbd_votes
# 156  Raging Bull  BiographyDramaSport     358918
#
# Movies of Comedy genre with the maximum number of votes:
#              title   genre imbd_votes
# 243  Life of Brian  Comedy     404989
#
# Movies of ComedyCrime genre with the maximum number of votes:
#       title        genre imbd_votes
# 118  Snatch  ComedyCrime     865529
#
# Movies of ComedyCrimeDrama genre with the maximum number of votes:
#                                         title             genre imbd_votes
# 164  Three Billboards Outside Ebbing Missouri  ComedyCrimeDrama     518061
#
# Movies of ComedyDrama genre with the maximum number of votes:
#                   title        genre imbd_votes
# 204  Dead Poets Society  ComedyDrama     501186
#
# Movies of ComedyDramaFamily genre with the maximum number of votes:
#        title              genre imbd_votes
# 127  The Kid  ComedyDramaFamily     128080
#
# Movies of ComedyDramaFantasy genre with the maximum number of votes:
#              title               genre imbd_votes
# 224  Groundhog Day  ComedyDramaFantasy     643209
#
# Movies of ComedyDramaRomance genre with the maximum number of votes:
#                 title               genre imbd_votes
# 25  Life Is Beautiful  ComedyDramaRomance     703472
#
# Movies of ComedyDramaThriller genre with the maximum number of votes:
#           title                genre imbd_votes
# 195  Wild Tales  ComedyDramaThriller     202365
#
# Movies of ComedyDramaWar genre with the maximum number of votes:
#                  title           genre imbd_votes
# 61  The Great Dictator  ComedyDramaWar     226622
#
# Movies of ComedyMusicRomance genre with the maximum number of votes:
#                 title               genre imbd_votes
# 128  Some Like It Hot  ComedyMusicRomance     270788
#
# Movies of ComedyMusicalRomance genre with the maximum number of votes:
#                   title                 genre imbd_votes
# 82  Singin' in the Rain  ComedyMusicalRomance     246258
#
# Movies of ComedyRomance genre with the maximum number of votes:
#       title          genre imbd_votes
# 101  Amélie  ComedyRomance     763676
#
# Movies of ComedyRomanceWar genre with the maximum number of votes:
#                   title             genre imbd_votes
# 226  To Be or Not to Be  ComedyRomanceWar      38888
#
# Movies of ComedyWar genre with the maximum number of votes:
#                                                 title      genre imbd_votes
# 67  Dr. Strangelove or: How I Learned to Stop Worr...  ComedyWar     495942
#
# Movies of CrimeDrama genre with the maximum number of votes:
#         title       genre imbd_votes
# 105  Scarface  CrimeDrama     853851
#
# Movies of CrimeDramaFantasy genre with the maximum number of votes:
#              title              genre imbd_votes
# 26  The Green Mile  CrimeDramaFantasy    1317747
#
# Movies of CrimeDramaFilm-Noir genre with the maximum number of votes:
#                 title                genre imbd_votes
# 103  Double Indemnity  CrimeDramaFilm-Noir     159388
#
# Movies of CrimeDramaMystery genre with the maximum number of votes:
#          title              genre imbd_votes
# 167  Prisoners  CrimeDramaMystery     731875
#
# Movies of CrimeDramaThriller genre with the maximum number of votes:
#                       title               genre imbd_votes
# 148  No Country for Old Men  CrimeDramaThriller     987934
#
# Movies of CrimeMysteryThriller genre with the maximum number of votes:
#    title                 genre imbd_votes
# 95     M  CrimeMysteryThriller     160158
#
# Movies of CrimeSci-Fi genre with the maximum number of votes:
#                   title        genre imbd_votes
# 102  A Clockwork Orange  CrimeSci-Fi     839209
#
# Movies of CrimeThriller genre with the maximum number of votes:
#      title          genre imbd_votes
# 169  Fargo  CrimeThriller     686205
#
# Movies of Drama genre with the maximum number of votes:
#                    title  genre imbd_votes
# 232  The Grapes of Wrath  Drama      95146
#
# Movies of DramaFamily genre with the maximum number of votes:
#                     title        genre imbd_votes
# 234  My Father and My Son  DramaFamily      87525
#
# Movies of DramaFamilyFantasy genre with the maximum number of votes:
#                     title               genre imbd_votes
# 20  It's a Wonderful Life  DramaFamilyFantasy     467723
#
# Movies of DramaFamilySport genre with the maximum number of votes:
#                   title             genre imbd_votes
# 174  Children of Heaven  DramaFamilySport      75814
#
# Movies of DramaFantasy genre with the maximum number of votes:
#                 title         genre imbd_votes
# 199  The Seventh Seal  DramaFantasy     187934
#
# Movies of DramaFantasyWar genre with the maximum number of votes:
#                title            genre imbd_votes
# 137  Pan's Labyrinth  DramaFantasyWar     675640
#
# Movies of DramaFilm-Noir genre with the maximum number of votes:
#            title           genre imbd_votes
# 58  Sunset Blvd.  DramaFilm-Noir     224680
#
# Movies of DramaFilm-NoirMystery genre with the maximum number of votes:
#        title                  genre imbd_votes
# 236  Rebecca  DramaFilm-NoirMystery     139329
#
# Movies of DramaHorror genre with the maximum number of votes:
#           title        genre imbd_votes
# 60  The Shining  DramaHorror    1035594
#
# Movies of DramaMusic genre with the maximum number of votes:
#        title       genre imbd_votes
# 41  Whiplash  DramaMusic     883875
#
# Movies of DramaMystery genre with the maximum number of votes:
#            title         genre imbd_votes
# 94  Citizen Kane  DramaMystery     446582
#
# Movies of DramaMysteryRomance genre with the maximum number of votes:
#                         title                genre imbd_votes
# 162  The Secret in Their Eyes  DramaMysteryRomance     212280
#
# Movies of DramaMysterySci-Fi genre with the maximum number of votes:
#            title               genre imbd_votes
# 40  The Prestige  DramaMysterySci-Fi    1348423
#
# Movies of DramaMysteryThriller genre with the maximum number of votes:
#          title                 genre imbd_votes
# 184  Gone Girl  DramaMysteryThriller     996836
#
# Movies of DramaMysteryWar genre with the maximum number of votes:
#              title            genre imbd_votes
# 52  Apocalypse Now  DramaMysteryWar     675280
#
# Movies of DramaRomance genre with the maximum number of votes:
#                 title         genre imbd_votes
# 80  Good Will Hunting  DramaRomance     987400
#
# Movies of DramaRomanceSci-Fi genre with the maximum number of votes:
#                                     title               genre imbd_votes
# 90  Eternal Sunshine of the Spotless Mind  DramaRomanceSci-Fi    1020184
#
# Movies of DramaRomanceThriller genre with the maximum number of votes:
#               title                 genre imbd_votes
# 238  The Handmaiden  DramaRomanceThriller     153302
#
# Movies of DramaRomanceWar genre with the maximum number of votes:
#                            title            genre imbd_votes
# 222  The Best Years of Our Lives  DramaRomanceWar      66194
#
# Movies of DramaSci-Fi genre with the maximum number of votes:
#           title        genre imbd_votes
# 114  Metropolis  DramaSci-Fi     176619
#
# Movies of DramaSport genre with the maximum number of votes:
#                    title       genre imbd_votes
# 173  Million Dollar Baby  DramaSport     694061
#
# Movies of DramaThriller genre with the maximum number of votes:
#        title          genre imbd_votes
# 33  Parasite  DramaThriller     828575
#
# Movies of DramaThrillerWar genre with the maximum number of votes:
#            title             genre imbd_votes
# 92  Come and See  DramaThrillerWar      83154
#
# Movies of DramaWar genre with the maximum number of votes:
#                      title     genre imbd_votes
# 133  Judgment at Nuremberg  DramaWar      78828
#
# Movies of DramaWestern genre with the maximum number of votes:
#           title         genre imbd_votes
# 139  Unforgiven  DramaWestern     416587
#
# Movies of Film-NoirMysteryThriller genre with the maximum number of votes:
#              title                     genre imbd_votes
# 188  The Third Man  Film-NoirMysteryThriller     173749
#
# Movies of Horror genre with the maximum number of votes:
#             title   genre imbd_votes
# 225  The Exorcist  Horror     415311
#
# Movies of HorrorMysterySci-Fi genre with the maximum number of votes:
#          title                genre imbd_votes
# 152  The Thing  HorrorMysterySci-Fi     432488
#
# Movies of HorrorMysteryThriller genre with the maximum number of votes:
#      title                  genre imbd_votes
# 32  Psycho  HorrorMysteryThriller     679428
#
# Movies of HorrorSci-Fi genre with the maximum number of votes:
#     title         genre imbd_votes
# 50  Alien  HorrorSci-Fi     892980
#
# Movies of MysteryRomanceThriller genre with the maximum number of votes:
#       title                   genre imbd_votes
# 99  Vertigo  MysteryRomanceThriller     407006
#
# Movies of MysteryThriller genre with the maximum number of votes:
#           title            genre imbd_votes
# 49  Rear Window  MysteryThriller     497077
#
# Movies of Western genre with the maximum number of votes:
#                            title    genre imbd_votes
# 47  Once Upon a Time in the West  Western     333809
